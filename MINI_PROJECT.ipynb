# %% [markdown]
# # **About the project**
# * Speech Emotion Recognition project . This project is emphasizing on recongnising the human emotion and states from the speech.

# %% [markdown]
# #**Data description**
# * The data used here is the RAVDESS dataset; **this is the Ryerson Audio-Visual Database** of Emotional Speech and Song dataset, and is free to download.
# * **Filename identifiers**
#
#   Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
#   Vocal channel (01 = speech, 02 = song).
#
#   ***Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).***
#
#   Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
#   Statement Used in the file for emotion depiction  (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
#   Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
#   Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# * **Filename example: 03-02-06-01-02-01-12.wav**
#
#  Audio-only (03)
#  Song (02)
#  Fearful (06)
#  Normal intensity (01)
#  Statement "dogs" (02)
#  1st Repetition (01)
#  12th Actor (12)
#  Female, as the actor ID number is even.

# %% [markdown]
# # **Model description**
# ## We have used two model for this project.
# ###  **Model 1**
#  * MLPClassifier-- Multi layer perceptron classifier model  is a feedforward ANN model that maps input data sets to a set of appropriate outputs.
#
# ### **Model 2**
#    * CNN -- Convolutional Neutral Network Model.CNN is designed to automatically and adaptively learn spatial hierarchies of features through backpropagation by using multiple building blocks, such as convolution layers, pooling layers, and fully connected layers.
#    * Traditonally 2D CNN (`Conv2D`) is used but here we are using 1D CNN (`Conv1D`) for our project.
#    * We have built this model using `TensorFlow Keras`.

# %% [markdown]
# #**Mounting google drive and unzipping the data file containing the audio.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip the data available in the drive an save it there for the our use.
#!unzip "/content/drive/MyDrive/speech-emotion-recognition-ravdess-data.zip" -d "drive/My Drive/MINI_PROJECT/"

# %% [markdown]
# ## Checking whether the data file is imported correctly or not.
# * Using libray `scipy.io.wavfile` for reading and writing the audio files and `IPython.display`to play audio file here for checking purpose.

# %%
#Loading the audio file.
D ="/content/drive/MyDrive/MINI_PROJECT/Actor_01/03-01-01-01-01-01-01.wav"

#Importing libraries
from scipy.io.wavfile import read , write
from IPython.display import Audio

#Reading the loaded audio file
fs,data = read(D)

#Playing the audio
Audio(data ,rate = fs,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Importing the library needed for data manipulation and visualization.

# %%
#Importing data manupulation library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Librosa and Soundfile
# * `Librosa` --  A python library to handle audio and music file.
# * `Soundfile` -- The soundfile module can read and write sound files. The soundfile module depends on the Python packages CFFI and NumPy, and the system library libsndfile. `soundfile.SoundFile` is used open sound files as an `SoundFile` objects.

# %%
#Importing librosa  library for audio file manipulation
# !pip3 install pydub
import librosa
import soundfile
from pydub import AudioSegment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %% [markdown]
# # Defining a function for extracting features from audio file so that we can use it for our model training.
# * Features are :-
#   * Frequency of the sample  = `sample_rate`
#   * Pitch of the sample = `chroma`. There are 12 different classes of pitches.
#   * Mel-Frequency Cepstrum Coefficients (MFCC) are understood to represent the filter (vocal tract) -- `mfcc`.
#   * Mel Spectrogram Frequency - `mel`
#   * `stft` -- Used to represent Short-Time Fourier Transform. It provides the time-localized frequency information for situations in which frequency components of a signal vary over time.

# %%
#soundfile Extract features (mfcc, chroma, mel) from a sound file
def extract_feature(file_name, mfcc, chroma, mel):
  '''
  This function take File name , Mel-Frequency Cepstrum coefficients(MFCC : A boolean value) ,
  Pitch of the sample (Chroma : A boolean value) and Mel-Spectrogram Frequency (mel : A boolean Value) as input and
  gives an array of containing values of mean of the features taken as input as an output.

  * It uses `librosa` , `numpy` and  `soundfile` library of python for output generation.
  '''
  with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float64")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
  if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
  return result

# %% [markdown]
# ## Defining a dictionary for emotions to be recognised by our model.
# * Since we are interested in only emotion recognition from the audio given. So we wil only focus on the emotion represntstion in the audio file. As emotions are represented by third group of digits in the name of the audion file we will use that group of digits as our target value.
#  * i.e  if file name is `03-02-06-01-02-01-12.wav` this then **06** is representing the emotion in the audio file. And here it is **Fearful**.
# *The differnt emotions according to the number are :
#    * 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised.

# %%
# Emotions Dictionary using Emotions representation in the RAVDESS dataset
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

# Emotions to observe
observed_emotions=['calm', 'happy', 'sad','surprised','neutral','disgust','fearful','angry']

# %% [markdown]
# ## We will using `.glob.glob` function in below cell.
# * This function finds all the pathnames matching a specified pattern in a directory. `*/*` is used where similar pattern is going to occur in the pathname.

# %%
#Load the data and extract features for each sound file
import glob , os
from sklearn.model_selection import train_test_split # For splitting the data into train and test set.
def load_data(test_size=0.2):

  '''
  This function takes `test_size` (i.e the amount data to be partiton into training and test set)
  as input  and gives training ans testing set of data as output.

  * It uses `.glob.glob` , `extraxt_feature()` and `os.path` functions for creating x and y dataset (i.e features and target )

  '''
  x,y=[],[]
  for file in glob.glob("/content/drive/My Drive/MINI_PROJECT/Actor_*/*.wav"):
        file_name=os.path.basename(file)
        sound = AudioSegment.from_wav(file)
        sound = sound.set_channels(1)
        sound.export(file, format="wav")
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    #print(x[:-10],y[:-10])
  return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %% [markdown]
# # Loading the dataset and splitting it into train and test sample.

# %%
#Split the dataset.
x_train,x_test,y_train,y_test  = load_data(test_size = 0.3)

# %% [markdown]
# ## Observing the splitted data .

# %%
x_train[10]
x_test[10]
# Out:
# array([-6.73297323e+02,  4.63995280e+01, -5.88779187e+00,  8.79814060e+00,
#         3.82632125e-01,  3.56197183e+00, -1.24896087e+01, -2.52479431e+00,
#        -1.77407578e+01, -3.26982420e+00, -1.16297770e+00, -5.70992379e+00,
#        -5.85328627e+00, -4.66392887e+00, -3.48890447e+00, -7.50262706e-01,
#        -4.62404685e+00, -3.87412415e+00, -4.38904722e+00, -4.69691760e+00,
#        -4.54324406e+00, -8.25112870e-01, -5.62591580e+00, -4.51547896e-01,
#        -2.00124931e+00, -9.24227196e-02, -6.90131949e-01,  2.37874043e+00,
#         3.38767848e+00,  3.49723575e+00,  2.64454079e+00,  3.51724835e+00,
#         3.00003784e+00,  9.42821371e-01,  2.11797361e-02,  5.23237538e-01,
#         6.88394193e-01,  2.03988613e+00,  2.78454697e+00,  1.47895354e+00,
#         7.12956099e-01,  7.19315332e-01,  6.44812030e-01,  6.09558948e-01,
#         5.83380852e-01,  5.69259905e-01,  5.68405559e-01,  5.54577553e-01,
#         6.19194549e-01,  6.45561144e-01,  6.59992326e-01,  6.92942359e-01,
#         5.57657209e-06,  1.73262270e-05,  2.16130998e-05,  1.38704702e-05,
#         1.11865359e-04,  3.47423965e-03,  1.64219727e-02,  6.38393531e-02,
#         9.93902859e-02,  4.76984584e-02,  9.50604242e-02,  2.74113463e-02,
#         3.11150194e-03,  6.76812901e-03,  1.01556925e-02,  1.37671545e-02,
#         3.31573938e-02,  4.19130488e-02,  2.44488104e-02,  1.60192221e-02,
#         7.51887861e-03,  5.44413260e-03,  9.24620023e-03,  6.07043625e-03,
#         4.53612938e-03,  8.97543693e-03,  6.51586773e-03,  4.24242640e-03,
#         1.57467864e-03,  1.58496533e-03,  3.13972695e-03,  1.16067177e-03,
#         4.64981193e-04,  1.40651057e-03,  2.01788374e-03,  8.69137832e-04,
#         5.69958068e-04,  3.52331936e-04,  3.34966019e-04,  3.87826875e-04,
#         3.42373851e-04,  6.57177775e-04,  8.60241380e-04,  6.09001083e-04,
#         1.18049871e-04,  2.55168560e-04,  8.38754961e-04,  1.03761639e-03,
#         6.54350199e-04,  3.88951429e-04,  1.80261172e-04,  7.11001545e-04,
#         5.15001035e-04,  3.27103321e-04,  3.61374395e-04,  2.37167891e-04,
#         1.88760208e-04,  4.43278541e-04,  4.07698818e-04,  2.19951604e-04,
#         1.82260089e-04,  1.15999888e-04,  2.13779256e-04,  2.06698712e-04,
#         2.09646778e-04,  2.19509835e-04,  1.80603446e-04,  9.55653021e-05,
#         7.58269089e-05,  5.82763712e-05,  5.31103449e-05,  8.67887359e-05,
#         1.63345983e-04,  2.48165779e-04,  1.73465301e-04,  2.09259783e-04,
#         1.78358644e-04,  2.38708110e-04,  2.06098533e-04,  1.57551705e-04,
#         1.28133383e-04,  1.97102093e-04,  3.03826243e-04,  4.90269239e-04,
#         6.12076552e-04,  5.29560547e-04,  7.87108526e-04,  8.91687018e-04,
#         9.37895247e-04,  6.40024385e-04,  5.13700558e-04,  2.89793920e-04,
#         2.24381769e-04,  4.57448716e-04,  3.20848925e-04,  4.20333390e-04,
#         2.80329366e-04,  2.30380088e-04,  3.26774741e-04,  2.82420579e-04,
#         2.26591937e-04,  2.27417550e-04,  2.37963059e-04,  1.67008897e-04,
#         2.12595725e-04,  2.25430735e-04,  1.76588317e-04,  2.48319301e-04,
#         2.35399180e-04,  1.63294442e-04,  1.32702309e-04,  1.60097226e-04,
#         1.69906955e-04,  1.33882108e-04,  8.75940273e-05,  5.30166488e-05,
#         2.01209058e-05,  1.09482792e-05,  8.86920590e-06,  7.12883669e-06,
#         5.72531726e-06,  3.29394638e-06,  2.01164690e-06,  1.59608211e-06,
#         1.29564286e-06,  5.64825207e-07,  6.35787737e-08,  7.78073426e-09])

# %% [markdown]
# ## Checking the features extracted.

# %%
print(f"Features extracted : {x_train.shape[1]}")
# Out:
# Features extracted : 180

# %% [markdown]
# # Training the model .
# * **Model used for training is MLP - Multi Layer Perceptron Classifier** .
#    * Parameter Used in the model : --
#   1).`alpha` -- Regularization term.
#   2).`batch_size` --No of samples that will passed through to the network at one time.
#   3).`epsilon` --
#   4).`hidden_layer_sizes` -- This parameter allows us to set the number of layers and number of nodes we wish to have in classifier. Given in afoem of a `tuple` (a,b) where  a is number of hidden layers and b is no nodes in each hidden layer.
#   5).`learning_rate` --Learning rate schedule for weight updates. We are using `adaptive` Lr here which keeps the learning rate constant as training loss keeps decreasing.
#   6).`max_iter` --Number of epochs maximum possible.

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(alpha = 0.01,batch_size = 254,epsilon = 1e-08 ,
                      hidden_layer_sizes =(300,),learning_rate="adaptive",
                      max_iter = 500)



model.fit(x_train,y_train)


y_pred  = model.predict(x_test)

# %% [markdown]
# ## Calculate the accracy of our model

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test,y_pred)

print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 51.39%

# %% [markdown]
# # HyperParameter Tuning
#  * Using the `GridSearchCv` for tuning the parameter and incresae the accuracy.

# %%
parameter_space = {
    'hidden_layer_sizes': [(50,), (200,), (100,)],
    'activation': ['identity','tanh', 'relu','logistic'],
    'solver': ['lbfgs','sgd', 'adam'],
    'alpha': [0.0001, 0.05,0.01],
    'learning_rate': ['constant','adaptive','invscaling'],
    'batch_size':[256,224]
}

# %% [markdown]
# ### GridSearchCv takes model , dictionary,  n-jobs and cv as input.
# * model  = ML Model to be tuned . Here we are using `MLPClassifier`.
# * dictionary  = A dictionary of parameters of model with different value.
# * N-jobs = The Number of parallel jobs to run. here its value is none i.e using all processors cores.
# * CV - cross validate value.

# %%
from sklearn.model_selection import GridSearchCV
model  = MLPClassifier(early_stopping = False)

clf = GridSearchCV(model, parameter_space, n_jobs=-1, cv=5)
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# GridSearchCV(cv=5, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['identity', 'tanh', 'relu', 'logistic'],
#                          'alpha': [0.0001, 0.05, 0.01],
#                          'batch_size': [256, 224],
#                          'hidden_layer_sizes': [(50,), (200,), (100,)],
#                          'learning_rate': ['constant', 'adaptive',
#                                            'invscaling'],
#                          'solver': ['lbfgs', 'sgd', 'adam']})

# %%
# Finding the best params.
clf.best_params_
# Out:
# {'activation': 'tanh',
#  'alpha': 0.01,
#  'batch_size': 224,
#  'hidden_layer_sizes': (200,),
#  'learning_rate': 'adaptive',
#  'solver': 'adam'}

# %%
# Predicting with beat params.
predict1 =clf.predict(x_test)

# %%
# Calculating the accuracy.
accuracy = accuracy_score(y_test,predict1)
accuracy
# Out:
# 0.6296296296296297

# %% [markdown]
# # Using Tensorflow to train and test the model.

# %% [markdown]
# ## Formatting the input data in according the model to be used ahead.
# * Collecting the formatted sample of the audio data in list form.
# * Libraries used here are `librosa` and features `mfccs` of the library.

# %%
lst = []

for subdir ,dirs ,files in os.walk("/content/drive/MyDrive/MINI_PROJECT"):
    for file in files:
        try:
            x,sample_rate = librosa.load(os.path.join(subdir,file),
                                         res_type = 'kaiser_fast')
            mfccs = np.mean(librosa.feature.mfcc(y = x , sr = sample_rate,n_mfcc = 40).T, axis =0)

            file_class = int(file[7:8])-1
            arr = mfccs, file_class
            lst.append(arr)
        except ValueError as err:
            print(err)
            continue

# %% [markdown]
# ### Converting the data into array from list datatype.
# * Function used is `np.asarray(`file_name`).

# %%
x1,y1 = zip(*lst)
x1, y1  = np.asarray(x1),np.asarray(y1)

# %% [markdown]
# ### Splitting and converting the data into required form.
# *  `train_test_split()` - Splitting the data into train and test dataset.

# %%
x_train1,x_valid,y_train1,y_valid = train_test_split(x1,y1,test_size = 0.1 , random_state  =42)
x_train2,x_test1,y_train2,y_test1 = train_test_split(x1,y1,test_size = 0.4 , random_state  =42)

# %%
print(f"Features extracted : {x_train1.shape[1]}")
# Out:
# Features extracted : 40

# %%
x_traincnn  = np.expand_dims(x_train1,axis=2)
x_validcnn = np.expand_dims(x_valid,axis=2)
x_testcnn = np.expand_dims(x_test1,axis =2)

# %%
print(x_traincnn.shape , x_testcnn.shape)
# Out:
# (2592, 40, 1) (1152, 40, 1)

# %% [markdown]
# ## Importing the important libaraies used to work in tensorflow.

# %%
import tensorflow as tf
import tensorflow_hub as hub


from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation
from tensorflow.keras.models import Sequential
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ## **Creating the model.**
# ### Model Description.
# * Here we are using Convolutional Neural Network Model build with `Tensorflow Keras`.
#  * It is a one dimensional alternative of Conv2D i.e ``ConV1D``.
# * We are building  a CNN with 1 hidden layer to keep things simple and prevent overfitting. The last fully connected layer has 8 outputs corresponding the number of total emotions.

# %%
model  = Sequential()
model.add(Conv1D(64,5,padding = 'valid',input_shape  =(40,1)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(8))
model.add(Activation("softmax"))

print(model.summary)
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x7efe4b64d2d0>>

# %% [markdown]
# ### Compile the model using `.compile` function.
#  * Important Terms :--
#   * Optimizer -- Optimizers are methods used to update the model's such as weights and learning rate in order to reduce the losses.
#   * Loss --Loss is used to calculate the gradients for the neural net.
#   * Metrics -- Way measure the correctness of our model prediction.
#   * EarlyStopping -- Used to stop the trainig of a model if repetition occurs.

# %%
# Compile the model using Adam's default learning rate
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Create 'EarlyStopping' callback
earlystopping_cb = tf.keras.callbacks.EarlyStopping(patience=10)

# %% [markdown]
# ####  **Summary of the model created**

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 36, 64)            384
#
#  activation (Activation)     (None, 36, 64)            0
#
#  dropout (Dropout)           (None, 36, 64)            0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 8)                 18440
#
#  activation_1 (Activation)   (None, 8)                 0
#
# =================================================================
# Total params: 18,824
# Trainable params: 18,824
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fitting the model

# %%
# %%time

#  Train the neural network
CNN_MODEL = model.fit(
    x=x_traincnn,
    y=y_train1,
    epochs=100,
    batch_size=32,
    validation_data = (x_valid, y_valid),
    callbacks=[earlystopping_cb]
)
# Out:
# Epoch 1/100
# 81/81 [==============================] - 2s 7ms/step - loss: 4.7386 - accuracy: 0.2041 - val_loss: 1.7177 - val_accuracy: 0.3681
# Epoch 2/100
# 81/81 [==============================] - 0s 5ms/step - loss: 2.1571 - accuracy: 0.3152 - val_loss: 1.5085 - val_accuracy: 0.4479
# Epoch 3/100
# 81/81 [==============================] - 0s 5ms/step - loss: 1.5569 - accuracy: 0.4306 - val_loss: 1.3352 - val_accuracy: 0.5035
# Epoch 4/100
# 81/81 [==============================] - 0s 5ms/step - loss: 1.3217 - accuracy: 0.5201 - val_loss: 1.2015 - val_accuracy: 0.5799
# Epoch 5/100
# 81/81 [==============================] - 0s 6ms/step - loss: 1.2402 - accuracy: 0.5351 - val_loss: 1.1180 - val_accuracy: 0.5903
# Epoch 6/100
# 81/81 [==============================] - 0s 5ms/step - loss: 1.1392 - accuracy: 0.5880 - val_loss: 1.1114 - val_accuracy: 0.6146
# Epoch 7/100
# 81/81 [==============================] - 0s 5ms/step - loss: 1.1016 - accuracy: 0.5795 - val_loss: 1.0337 - val_accuracy: 0.6319
# Epoch 8/100
# 81/81 [==============================] - 0s 5ms/step - loss: 1.0368 - accuracy: 0.6204 - val_loss: 1.0294 - val_accuracy: 0.6424
# Epoch 9/100
# 81/81 [==============================] - 0s 5ms/step - loss: 1.0000 - accuracy: 0.6370 - val_loss: 0.9985 - val_accuracy: 0.6389
# Epoch 10/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.9439 - accuracy: 0.6555 - val_loss: 0.9556 - val_accuracy: 0.6667
# Epoch 11/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.9193 - accuracy: 0.6593 - val_loss: 0.9010 - val_accuracy: 0.6910
# Epoch 12/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8790 - accuracy: 0.6806 - val_loss: 0.8932 - val_accuracy: 0.6840
# Epoch 13/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8567 - accuracy: 0.6863 - val_loss: 0.9198 - val_accuracy: 0.6667
# Epoch 14/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8155 - accuracy: 0.7064 - val_loss: 0.8089 - val_accuracy: 0.7118
# Epoch 15/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8160 - accuracy: 0.7041 - val_loss: 0.7684 - val_accuracy: 0.7188
# Epoch 16/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.7628 - accuracy: 0.7203 - val_loss: 0.7976 - val_accuracy: 0.7153
# Epoch 17/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.7480 - accuracy: 0.7319 - val_loss: 0.7738 - val_accuracy: 0.7153
# Epoch 18/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.7336 - accuracy: 0.7222 - val_loss: 0.7558 - val_accuracy: 0.7396
# Epoch 19/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.7343 - accuracy: 0.7357 - val_loss: 0.7956 - val_accuracy: 0.7083
# Epoch 20/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.6809 - accuracy: 0.7573 - val_loss: 0.7126 - val_accuracy: 0.7500
# Epoch 21/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.6493 - accuracy: 0.7774 - val_loss: 0.7452 - val_accuracy: 0.7500
# Epoch 22/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.6486 - accuracy: 0.7658 - val_loss: 0.7022 - val_accuracy: 0.7396
# Epoch 23/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.6265 - accuracy: 0.7816 - val_loss: 0.6256 - val_accuracy: 0.7986
# Epoch 24/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.6311 - accuracy: 0.7720 - val_loss: 0.7310 - val_accuracy: 0.7396
# Epoch 25/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.6170 - accuracy: 0.7731 - val_loss: 0.6277 - val_accuracy: 0.7951
# Epoch 26/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5770 - accuracy: 0.7955 - val_loss: 0.6233 - val_accuracy: 0.7882
# Epoch 27/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5957 - accuracy: 0.7863 - val_loss: 0.6785 - val_accuracy: 0.7743
# Epoch 28/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5697 - accuracy: 0.8017 - val_loss: 0.7023 - val_accuracy: 0.7674
# Epoch 29/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5681 - accuracy: 0.7894 - val_loss: 0.6200 - val_accuracy: 0.7812
# Epoch 30/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5514 - accuracy: 0.8017 - val_loss: 0.5757 - val_accuracy: 0.8056
# Epoch 31/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5538 - accuracy: 0.7963 - val_loss: 0.5671 - val_accuracy: 0.8090
# Epoch 32/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5681 - accuracy: 0.7975 - val_loss: 0.6257 - val_accuracy: 0.7569
# Epoch 33/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5295 - accuracy: 0.8113 - val_loss: 0.6301 - val_accuracy: 0.7847
# Epoch 34/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.8144 - val_loss: 0.5536 - val_accuracy: 0.8125
# Epoch 35/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5127 - accuracy: 0.8164 - val_loss: 0.5804 - val_accuracy: 0.8229
# Epoch 36/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5191 - accuracy: 0.8144 - val_loss: 0.5880 - val_accuracy: 0.8021
# Epoch 37/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4995 - accuracy: 0.8218 - val_loss: 0.5546 - val_accuracy: 0.7882
# Epoch 38/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4854 - accuracy: 0.8229 - val_loss: 0.5531 - val_accuracy: 0.8160
# Epoch 39/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5001 - accuracy: 0.8218 - val_loss: 0.5474 - val_accuracy: 0.8125
# Epoch 40/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4825 - accuracy: 0.8241 - val_loss: 0.5399 - val_accuracy: 0.8160
# Epoch 41/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4522 - accuracy: 0.8333 - val_loss: 0.5097 - val_accuracy: 0.8368
# Epoch 42/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4645 - accuracy: 0.8302 - val_loss: 0.5679 - val_accuracy: 0.7882
# Epoch 43/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4438 - accuracy: 0.8472 - val_loss: 0.4907 - val_accuracy: 0.8264
# Epoch 44/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4388 - accuracy: 0.8441 - val_loss: 0.5232 - val_accuracy: 0.8299
# Epoch 45/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4671 - accuracy: 0.8387 - val_loss: 0.5370 - val_accuracy: 0.8264
# Epoch 46/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4404 - accuracy: 0.8461 - val_loss: 0.5101 - val_accuracy: 0.8194
# Epoch 47/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4216 - accuracy: 0.8526 - val_loss: 0.4698 - val_accuracy: 0.8472
# Epoch 48/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4319 - accuracy: 0.8449 - val_loss: 0.6078 - val_accuracy: 0.7847
# Epoch 49/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4335 - accuracy: 0.8511 - val_loss: 0.4557 - val_accuracy: 0.8576
# Epoch 50/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4268 - accuracy: 0.8445 - val_loss: 0.4664 - val_accuracy: 0.8681
# Epoch 51/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4099 - accuracy: 0.8576 - val_loss: 0.4889 - val_accuracy: 0.8333
# Epoch 52/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4214 - accuracy: 0.8484 - val_loss: 0.4631 - val_accuracy: 0.8715
# Epoch 53/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3954 - accuracy: 0.8553 - val_loss: 0.4584 - val_accuracy: 0.8507
# Epoch 54/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3967 - accuracy: 0.8565 - val_loss: 0.4936 - val_accuracy: 0.8576
# Epoch 55/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3855 - accuracy: 0.8642 - val_loss: 0.4246 - val_accuracy: 0.8715
# Epoch 56/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3906 - accuracy: 0.8630 - val_loss: 0.4483 - val_accuracy: 0.8611
# Epoch 57/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3888 - accuracy: 0.8650 - val_loss: 0.4691 - val_accuracy: 0.8333
# Epoch 58/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3715 - accuracy: 0.8634 - val_loss: 0.4709 - val_accuracy: 0.8611
# Epoch 59/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3699 - accuracy: 0.8661 - val_loss: 0.3934 - val_accuracy: 0.8750
# Epoch 60/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3862 - accuracy: 0.8661 - val_loss: 0.4402 - val_accuracy: 0.8576
# Epoch 61/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3593 - accuracy: 0.8727 - val_loss: 0.4514 - val_accuracy: 0.8611
# Epoch 62/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3632 - accuracy: 0.8735 - val_loss: 0.4173 - val_accuracy: 0.8438
# Epoch 63/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3695 - accuracy: 0.8661 - val_loss: 0.4462 - val_accuracy: 0.8542
# Epoch 64/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3921 - accuracy: 0.8561 - val_loss: 0.4996 - val_accuracy: 0.8229
# Epoch 65/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.4027 - accuracy: 0.8511 - val_loss: 0.4265 - val_accuracy: 0.8542
# Epoch 66/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3732 - accuracy: 0.8580 - val_loss: 0.4202 - val_accuracy: 0.8611
# Epoch 67/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3524 - accuracy: 0.8704 - val_loss: 0.4039 - val_accuracy: 0.8715
# Epoch 68/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3714 - accuracy: 0.8650 - val_loss: 0.3904 - val_accuracy: 0.8819
# Epoch 69/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3487 - accuracy: 0.8750 - val_loss: 0.3904 - val_accuracy: 0.8819
# Epoch 70/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3529 - accuracy: 0.8792 - val_loss: 0.3932 - val_accuracy: 0.8681
# Epoch 71/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3417 - accuracy: 0.8754 - val_loss: 0.4672 - val_accuracy: 0.8333
# Epoch 72/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3432 - accuracy: 0.8777 - val_loss: 0.4784 - val_accuracy: 0.8194
# Epoch 73/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3096 - accuracy: 0.8935 - val_loss: 0.4142 - val_accuracy: 0.8646
# Epoch 74/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3475 - accuracy: 0.8785 - val_loss: 0.3747 - val_accuracy: 0.8715
# Epoch 75/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3134 - accuracy: 0.8889 - val_loss: 0.3825 - val_accuracy: 0.8924
# Epoch 76/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3332 - accuracy: 0.8789 - val_loss: 0.3848 - val_accuracy: 0.8750
# Epoch 77/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3379 - accuracy: 0.8812 - val_loss: 0.3291 - val_accuracy: 0.9062
# Epoch 78/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3114 - accuracy: 0.8931 - val_loss: 0.3409 - val_accuracy: 0.8958
# Epoch 79/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3045 - accuracy: 0.8962 - val_loss: 0.3921 - val_accuracy: 0.8715
# Epoch 80/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3152 - accuracy: 0.8908 - val_loss: 0.3240 - val_accuracy: 0.8993
# Epoch 81/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.8951 - val_loss: 0.3693 - val_accuracy: 0.8889
# Epoch 82/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3120 - accuracy: 0.8866 - val_loss: 0.3470 - val_accuracy: 0.8785
# Epoch 83/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3296 - accuracy: 0.8785 - val_loss: 0.3565 - val_accuracy: 0.8854
# Epoch 84/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2938 - accuracy: 0.8966 - val_loss: 0.3193 - val_accuracy: 0.9062
# Epoch 85/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3123 - accuracy: 0.8920 - val_loss: 0.3334 - val_accuracy: 0.8993
# Epoch 86/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3015 - accuracy: 0.8920 - val_loss: 0.3397 - val_accuracy: 0.9028
# Epoch 87/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2838 - accuracy: 0.8970 - val_loss: 0.3125 - val_accuracy: 0.9167
# Epoch 88/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2909 - accuracy: 0.8966 - val_loss: 0.3242 - val_accuracy: 0.9062
# Epoch 89/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2731 - accuracy: 0.9008 - val_loss: 0.4068 - val_accuracy: 0.8542
# Epoch 90/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3034 - accuracy: 0.8947 - val_loss: 0.3355 - val_accuracy: 0.8924
# Epoch 91/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2899 - accuracy: 0.9024 - val_loss: 0.3730 - val_accuracy: 0.8542
# Epoch 92/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3033 - accuracy: 0.8958 - val_loss: 0.3679 - val_accuracy: 0.8646
# Epoch 93/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2802 - accuracy: 0.8985 - val_loss: 0.3467 - val_accuracy: 0.8924
# Epoch 94/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2823 - accuracy: 0.9047 - val_loss: 0.3416 - val_accuracy: 0.8993
# Epoch 95/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3196 - accuracy: 0.8846 - val_loss: 0.3090 - val_accuracy: 0.9097
# Epoch 96/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2801 - accuracy: 0.8954 - val_loss: 0.3070 - val_accuracy: 0.9167
# Epoch 97/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2819 - accuracy: 0.9012 - val_loss: 0.3175 - val_accuracy: 0.9062
# Epoch 98/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2585 - accuracy: 0.9082 - val_loss: 0.3229 - val_accuracy: 0.8889
# Epoch 99/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2870 - accuracy: 0.8939 - val_loss: 0.3486 - val_accuracy: 0.8819
# Epoch 100/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.2941 - accuracy: 0.8958 - val_loss: 0.3200 - val_accuracy: 0.9167
# CPU times: user 49.8 s, sys: 4.04 s, total: 53.9 s
# Wall time: 44 s

# %% [markdown]
# ## Plotting the results of the model trainied.

# %%
plt.plot(CNN_MODEL.history['loss'])
plt.plot(CNN_MODEL.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

# %%
plt.plot(CNN_MODEL.history['accuracy'])
plt.plot(CNN_MODEL.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')



plt.show()

# %% [markdown]
# ## **Plotting  the Confusion matrix of the model**.
# * `Confusion Matrix`-- A confusion matrix is a quick way to compare the labels a model predicts and the actual labels it as supposed to predict.
# It gives us an idea where model is getting confused.

# %%
#Predictions
predictions = model.predict(x_test1)

pred = []

for i in predictions:
    pred.append(np.argmax(i))

from sklearn.metrics import ConfusionMatrixDisplay

labels = {'angry':0,'disgust':1,'fear':2,'happy':3,'neutral':4,'sad':5,'surprise':6}

def plot_confusion_matrices(y_true, y_pred):
    '''
    This Function take True and predicted value of the test data and
    plot a confusion matrix.
    '''

    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

    # Plots the standard confusion matrix
    ax1.set_title("Confusion Matrix (counts)")
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=labels, ax=ax1)

    # Plots the normalized confusion matrix
    ax2.set_title("Confusion Matrix (ratios)")
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=labels, normalize="true", ax=ax2)

    plt.show()

# Plot confusion matrices
plot_confusion_matrices(y_test1, pred)
# Out:
# 36/36 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Predicting the result from the model on a test set.
# * Calculating the accuracy of the model on the test set of data.

# %%
# Collect loss and accuracy for the test set
loss_te, accuracy_te = model.evaluate(x_test1, y_test1)

print("Test loss: {:.2f}".format(loss_te))
print("Test accuracy: {:.2f}%".format(100 * accuracy_te))
# Out:
# 36/36 [==============================] - 0s 2ms/step - loss: 0.1531 - accuracy: 0.9670
# Test loss: 0.15
# Test accuracy: 96.70%
